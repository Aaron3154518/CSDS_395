# %%
# !pip install spotipy
# Out:
# ...
#   Using cached spotipy-2.23.0-py3-none-any.whl (29 kB)
# ...
#   Using cached redis-4.5.4-py3-none-any.whl (238 kB)
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
import requests

# %%
CLIENT_ID = 'e43351ba7f1841eab1bfbc394703de3f'
CLIENT_SECRET = '75daef945b904c9e85f424899db553b9'
AUTH_URL = "https://accounts.spotify.com/api/token"
headers = {
    "Content-Type": "application/x-www-form-urlencoded",
}
data = {
    "grant_type": "client_credentials",
    "client_id": CLIENT_ID,
    "client_secret": CLIENT_SECRET,
}

response = requests.post(AUTH_URL, headers=headers, data=data)
if response.status_code == 200:
    access_token = response.json()["access_token"]
    print("Access token:", access_token)
else:
    print("Failed to obtain access token:", response.content)
# Out:
# Access token: BQBvpFx5SBGqqLfaNszlTqboESoT4ebk7fh5LM5oWWKvdljdrp05lGri26e94rAMoSYHmiA6g4IJts_vJf2j0nZN2Ogo0561Y71vBoq9Gk9eRnPT99gh

# %%
# followed tutorial to access saved user tracks:https://python.plainenglish.io/bored-of-libraries-heres-how-to-connect-to-the-spotify-api-using-pure-python-bd31e9e3d88a
import requests
from urllib.parse import urlencode
import base64
import webbrowser

# %%
client_id = 'e43351ba7f1841eab1bfbc394703de3f'
client_secret = '75daef945b904c9e85f424899db553b9'

auth_headers = {
    "client_id": client_id,
    "response_type": "code",
    "redirect_uri": "http://localhost:3000",
    "scope": "user-library-read"
}

webbrowser.open("https://accounts.spotify.com/authorize?" + urlencode(auth_headers))
# Out:
# True

# %%
code="AQAwCb9SBjDwuY-OYOh9hSu71gRUZOxRUWznkMorDXqdXSL4P9BuZls2GpkPRqd2qZ6Y1dGuaJMjos2qrNg_akIMH8K8v5LCM7dUObV3SN5dJJ7XYgyyI2J49GNicZLFujmN43cD_ValLFCorA8zQjDKpbG9jzAfmn_HlRE1fZlTQVY7oCkkaDbRdvM"

# %%
encoded_credentials = base64.b64encode(client_id.encode() + b':' + client_secret.encode()).decode("utf-8")
token_headers = {
    "Authorization": "Basic " + encoded_credentials,
    "Content-Type": "application/x-www-form-urlencoded"
}
token_data = {
    "grant_type": "authorization_code",
    "code": code,
    "redirect_uri": "http://localhost:3000"
}
r = requests.post("https://accounts.spotify.com/api/token", data=token_data, headers=token_headers)
token = r.json()["access_token"]
print(token)
# Out:
# BQDSD2RnzOMlOcS-2iVymrFgCypNUs8xr9lYqMYnD7MoZVCE637kDQJ2D0z0CiroAB4ERuLSTk2i2GNkxTALNVI3mo1K_Zyb_2BPF3NS__EhO_l2sggNI-WfLexvoW_3c7oPAfM3Cxrp2vBE0vKGuZI-9qx306C7SLbyF2DBof6YbINhGF8zzX66d9cxRBWcKA

# %%
user_headers = {
    "Authorization": "Bearer " + token,
    "Content-Type": "application/json"
}
user_params = {
    "limit": 50
}
user_tracks_response = requests.get("https://api.spotify.com/v1/me/tracks", params=user_params, headers=user_headers)
print(user_tracks_response.json())
# Out:
# {'href': 'https://api.spotify.com/v1/me/tracks?offset=0&limit=50', 'items': [{'added_at': '2023-04-28T20:14:09Z', 'track': {'album': {'album_group': 'single', 'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/45eNHdiiabvmbp4erw26rg'}, 'href': 'https://api.spotify.com/v1/artists/45eNHdiiabvmbp4erw26rg', 'id': '45eNHdiiabvmbp4erw26rg', 'name': 'ILLENIUM', 'type': 'artist', 'uri': 'spotify:artist:45eNHdiiabvmbp4erw26rg'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/50JJSqHUf2RQ9xsHs0KMHg'}, 'href': 'https://api.spotify.com/v1/artists/50JJSqHUf2RQ9xsHs0KMHg', 'id': '50JJSqHUf2RQ9xsHs0KMHg', 'name': 'Jon Bellion', 'type': 'artist', 'uri': 'spotify:artist:50JJSqHUf2RQ9xsHs0KMHg'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', '
# ...

# %%
user_tracks=user_tracks_response.json()
user_tracks['items'][0]['track']['id']
# Out:
# '6pooRNiLyYpxZeIA5kJ5EX'

# %%
song_ids=[]
for x in range(len(user_tracks['items'])):
    track_id=user_tracks['items'][x]['track']['id']
    song_ids.append(track_id)

# %%
user={}
user['id']='vsharma3600'
user['likedSongs']=song_ids

# %%
user_df=pd.DataFrame([user])
user_df.to_csv("user.csv", index=False)

# %%
#saved user saved songs
track_id = song_ids[0]
ACCESS_TOKEN = access_token
TRACK_ENDPOINT = "https://api.spotify.com/v1/tracks/"+track_id
headers = {
    "Authorization": "Bearer " + ACCESS_TOKEN,
}
response = requests.get(TRACK_ENDPOINT, headers=headers)
if response.status_code == 200:
    track= response.json()
else:
    print("Failed to get track:", response.content)
temp={'id':track['album']['id'], 'name':track['album']['name'], 'uri':track['album']['uri']}
track['album']=temp
for i in range(len(track['artists'])):
    track['artists'][i]=track['artists'][i]['name']
keys_to_remove = ['available_markets', 'disc_number', 'explicit', 'external_ids', 'is_local', 'track_number']
for key in keys_to_remove:
    del track[key]
FEATURE_ENDPOINT = "https://api.spotify.com/v1/audio-features/"+track_id
headers = {
    "Authorization": "Bearer " + ACCESS_TOKEN,
}

response = requests.get(FEATURE_ENDPOINT, headers=headers)
if response.status_code == 200:
    feature_info = response.json()
else:
    print("Failed to get track features:", response.content)
track['danceability'] = feature_info['danceability']
track['energy'] = feature_info['energy']
track['key'] = feature_info['key']
track['loudness'] = feature_info['loudness']
track['mode'] = feature_info['mode']
track['speechiness'] = feature_info['speechiness']
track['acousticness'] = feature_info['acousticness']
track['instrumentalness'] = feature_info['instrumentalness']
track['liveness'] = feature_info['liveness']
track['valence'] = feature_info['valence']
track['tempo'] = feature_info['tempo']
track['duration_ms'] = feature_info['duration_ms']
track['time_signature'] = feature_info['time_signature']
track['airtist_name']=track['artists']
song_df=pd.DataFrame([track])
song_df
# Out:
#                                                album                  artists  \
# 0  {'id': '4IYvXJnU8zPRzPPTu4dJUl', 'name': 'Good...  [ILLENIUM, Jon Bellion]
#
#    duration_ms                                      external_urls  \
# 0       216668  {'spotify': 'https://open.spotify.com/track/6p...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/6pooRNiLyYpx...  6pooRNiLyYpxZeIA5kJ5EX
#
#                                         name  popularity preview_url   type  \
# 0  Good Things Fall Apart (with Jon Bellion)          63        None  track
#
#    ... loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0  ...   -5.453     1       0.0318        0.0128                 0     0.118
#
#    valence    tempo  time_signature             airtist_name
# 0    0.442  144.033               4  [ILLENIUM, Jon Bellion]
#
# [1 rows x 24 columns]

# %%
for x in range(len(song_ids)-1):
    track_id = song_ids[x+1]
    ACCESS_TOKEN = access_token
    TRACK_ENDPOINT = "https://api.spotify.com/v1/tracks/"+track_id
    headers = {
        "Authorization": "Bearer " + ACCESS_TOKEN,
    }
    response = requests.get(TRACK_ENDPOINT, headers=headers)
    if response.status_code == 200:
        track= response.json()
    else:
        print("Failed to get track:", response.content)
    temp={'id':track['album']['id'], 'name':track['album']['name'], 'uri':track['album']['uri']}
    track['album']=temp
    for i in range(len(track['artists'])):
        track['artists'][i]=track['artists'][i]['name']
    keys_to_remove = ['available_markets', 'disc_number', 'explicit', 'external_ids', 'is_local', 'track_number']
    for key in keys_to_remove:
        del track[key]
    FEATURE_ENDPOINT = "https://api.spotify.com/v1/audio-features/"+track_id
    headers = {
        "Authorization": "Bearer " + ACCESS_TOKEN,
    }

    response = requests.get(FEATURE_ENDPOINT, headers=headers)
    if response.status_code == 200:
        feature_info = response.json()
    else:
        print("Failed to get track features:", response.content)
    track['danceability'] = feature_info['danceability']
    track['energy'] = feature_info['energy']
    track['key'] = feature_info['key']
    track['loudness'] = feature_info['loudness']
    track['mode'] = feature_info['mode']
    track['speechiness'] = feature_info['speechiness']
    track['acousticness'] = feature_info['acousticness']
    track['instrumentalness'] = feature_info['instrumentalness']
    track['liveness'] = feature_info['liveness']
    track['valence'] = feature_info['valence']
    track['tempo'] = feature_info['tempo']
    track['duration_ms'] = feature_info['duration_ms']
    track['time_signature'] = feature_info['time_signature']
    track['airtist_name']=track['artists']
    song_df = song_df.append(track, ignore_index=True)
# Out:
# C:\Users\vshar\AppData\Local\Temp\ipykernel_19316\3416507736.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   song_df = song_df.append(track, ignore_index=True)
# C:\Users\vshar\AppData\Local\Temp\ipykernel_19316\3416507736.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   song_df = song_df.append(track, ignore_index=True)
# C:\Users\vshar\AppData\Local\Temp\ipykernel_19316\3416507736.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   song_df = song_df.append(track, ignore_index=True)
# C:\Users\vshar\AppData\Local\Temp\ipykernel_19316\3416507736.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
song_df
# Out:
#                                                 album  \
# 0   {'id': '4IYvXJnU8zPRzPPTu4dJUl', 'name': 'Good...
# 1   {'id': '2Y5NgR5CQJeqAz5iYN5agm', 'name': 'Lull...
# 2   {'id': '007DWn799UWvfY1wwZeENR', 'name': 'i am...
# 3   {'id': '2uDTi1PlpSpvAv7IRAoAEU', 'name': 'HIGH...
# 4   {'id': '4yP0hdKOZPNshxUOjY0cZj', 'name': 'Afte...
# 5   {'id': '4g1ZRSobMefqF6nelkgibi', 'name': 'Holl...
# 6   {'id': '4g1ZRSobMefqF6nelkgibi', 'name': 'Holl...
# 7   {'id': '4g1ZRSobMefqF6nelkgibi', 'name': 'Holl...
# 8   {'id': '4g1ZRSobMefqF6nelkgibi', 'name': 'Holl...
# 9   {'id': '4g1ZRSobMefqF6nelkgibi', 'name': 'Holl...
# 10  {'id': '5n1GSzC1Reao29ScnpLYqp', 'name': 'Dyin...
# 11  {'id': '4QcXq4vTVN7dFb7bZa9jG2', 'name': 'Phar...
# 12  {'id': '18C3JLfjKrkCKZubEhqJuw', 'name': 'Holy...
# 13  {'id': '7DNmxxEuJe19wNVrinaXx4', 'name': 'The ...
# 14  {'id': '4QcXq4vTVN7dFb7bZa9jG2', 'name': 'Phar...
# 15  {'id': '1QrYKuMTMLwpTwzOFhfnOk', 'name': 'Fait...
# ...

# %%
song_df.to_csv('song.csv', index=False)

# %%
#failed attempt to access saved user songs
ACCESS_TOKEN = access_token
TRACK_ENDPOINT = "https://api.spotify.com/v1/me"
headers = {
    "Authorization": "Bearer " + ACCESS_TOKEN,
}
response = requests.get(TRACK_ENDPOINT, headers=headers)
if response.status_code == 200:
    track_info = response.json()
else:
    print("Failed to get track:", response.content)
# Out:
# Failed to get track: b'{\n  "error" : {\n    "status" : 401,\n    "message" : "Unauthorized."\n  }\n}'

# %%
ACCESS_TOKEN = access_token
TRACK_ENDPOINT = "https://api.spotify.com/v1/me/tracks"
headers = {
    "Authorization": "Bearer " + ACCESS_TOKEN,
}
response = requests.get(TRACK_ENDPOINT, headers=headers)
if response.status_code == 200:
    track_info = response.json()
    print(track_info)
else:
    print("Failed to get saved tracks:", response.content)
# Out:
# Failed to get saved tracks: b'{\n  "error" : {\n    "status" : 403,\n    "message" : "Forbidden."\n  }\n}'

# %%
#below is a failed attempt to use Spotipy
cid='724e4f836b96475180e703abe692c73c'
secret='2a800df386ea43d9ba4d7b2da1c935c2'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
track_URI="spotify:track:0UaMYEvWZi0ZqiDOoHU3YI"
track=sp.track(track_URI)
# Out:
# {'album': {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wIVse2owClT7go1WT98tk'},
#     'href': 'https://api.spotify.com/v1/artists/2wIVse2owClT7go1WT98tk',
#     'id': '2wIVse2owClT7go1WT98tk',
#     'name': 'Missy Elliott',
#     'type': 'artist',
#     'uri': 'spotify:artist:2wIVse2owClT7go1WT98tk'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
# ...

# %%
#script to call api for playlist and clean data
ACCESS_TOKEN = access_token
PLAYLIST_ENDPOINT = "https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M"
headers = {
    "Authorization": "Bearer " + ACCESS_TOKEN,
}
response = requests.get(PLAYLIST_ENDPOINT, headers=headers)
if response.status_code == 200:
    playlist_info = response.json()
    print("Playlist name:", playlist_info["name"])
else:
    print("Failed to get track:", response.content)
# Out:
# Playlist name: Today's Top Hits

# %%
playlist_info['id']
# Out:
# '37i9dQZF1DXcBWIGoYBM5M'

# %%
playlist={}
playlist['id']=playlist_info['id']
playlist['name']=playlist_info["name"]
playlist['followers']=playlist_info["followers"]['total']

# %%
type(playlist_info['tracks'])
# Out:
# dict

# %%
playlist
# Out:
# {'id': '37i9dQZF1DXcBWIGoYBM5M',
#  'name': "Today's Top Hits",
#  'followers': 33567412}

# %%
ids=['37i9dQZF1DXcBWIGoYBM5M','37i9dQZEVXbMDoHDwVN2tF','37i9dQZF1DX0XUsuxWHRQd','37i9dQZF1DX10zKzsJ2jva','37i9dQZF1DWY7IeIP1cdjF',
    '37i9dQZF1DWXRqgorJj26U', '37i9dQZF1DWWMOmoXKqHTD','37i9dQZF1DX4o1oenSJRJd','37i9dQZF1DX4UtSsGT1Sbe','37i9dQZF1DX76Wlfdnj7AP',
    '37i9dQZF1DXbTxeAdrVG2l', '37i9dQZF1DX4WYpdgoIcn6','37i9dQZF1DX3rxVfibe1L0','37i9dQZF1DX1lVhptIYRda','37i9dQZF1DWSqmBTGDYngZ',
    '37i9dQZF1DX186v583rmzp','37i9dQZF1DX4sWSpwq3LiO','0vvXsWCC9xrXsKd4FyS8kM','37i9dQZF1DXdSjVZQzv2tl','37i9dQZF1DX08mhnhv6g9b',
    '37i9dQZF1DWY4xHQp97fN6','37i9dQZF1DXdxcBWuJkbcy','37i9dQZF1DX4dyzvuaRJ0n','37i9dQZF1DXdPec7aLTmlC','37i9dQZF1DX6aTaZa0K6VA',
    '37i9dQZF1DX4olOMiqFeqU','37i9dQZF1DX1tyCD9QhIWF','5q9PUsxGCHheWq9tNabqa7','37i9dQZF1DX6z20IXmBjWI','37i9dQZF1DX32NsLKyzScr',
    '37i9dQZF1DX8kP0ioXjxIA','37i9dQZF1DX6GwdWRQMQpq','37i9dQZF1EQn4jwNIohw50','1L2HV8dhQOLpTMabQ9poxM','37i9dQZF1DWWwaxRea1LWS']

# %%
import pandas as pd
df = pd.DataFrame([playlist])
df
# Out:
#                        id              name  followers
# 0  37i9dQZF1DXcBWIGoYBM5M  Today's Top Hits   33567412

# %%
for i in range(len(ids)-1):
    ACCESS_TOKEN = access_token
    PLAYLIST_ENDPOINT = "https://api.spotify.com/v1/playlists/"+ids[i+1]

    headers = {
        "Authorization": "Bearer " + ACCESS_TOKEN,
    }
    response = requests.get(PLAYLIST_ENDPOINT, headers=headers)
    if response.status_code == 200:
        playlist_info = response.json()
    else:
        print("Failed to get Playlist (View Error):", response.content)
    playlist={}
    playlist['id']=playlist_info['id']
    playlist['name']=playlist_info["name"]
    playlist['followers']=playlist_info["followers"]['total']
    df = df.append(playlist, ignore_index=True)
# Out:
# C:\Users\vshar\AppData\Local\Temp\ipykernel_19316\2231280517.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(playlist, ignore_index=True)
# C:\Users\vshar\AppData\Local\Temp\ipykernel_19316\2231280517.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(playlist, ignore_index=True)
# C:\Users\vshar\AppData\Local\Temp\ipykernel_19316\2231280517.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(playlist, ignore_index=True)
# C:\Users\vshar\AppData\Local\Temp\ipykernel_19316\2231280517.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df
# Out:
#                          id  \
# 0    37i9dQZF1DXcBWIGoYBM5M
# 1    37i9dQZEVXbMDoHDwVN2tF
# 2    37i9dQZF1DX0XUsuxWHRQd
# 3    37i9dQZF1DX10zKzsJ2jva
# 4    37i9dQZF1DWY7IeIP1cdjF
# ..                      ...
# 100  37i9dQZF1DX8kP0ioXjxIA
# 101  37i9dQZF1DX6GwdWRQMQpq
# 102  37i9dQZF1EQn4jwNIohw50
# 103  1L2HV8dhQOLpTMabQ9poxM
# 104  37i9dQZF1DWWwaxRea1LWS
#
#                                                   name  followers
# 0                                     Today's Top Hits   33567412
# 1                                      Top 50 - Global   17310753
# 2                                            RapCaviar   15255613
# 3                                          Viva Latino   13707809
# 4                                      Baila Reggaeton   10923198
# ..                                                 ...        ...
# 100                                  This Is BLACKPINK    2869573
# 101                                     Feelin' Myself    2819504
# ...

# %%
len(df['id'])
# Out:
# 105

# %%
df['id'][0]
# Out:
# '37i9dQZF1DXcBWIGoYBM5M'

# %%
df.to_csv("playlists.csv", index=False)

# %%
df['id'][0]
# Out:
# '2b2GHWESCWEuHiCZ2Skedp'

# %%
#script to call api for album and clean data
for x in range(len(df['id'])):
    id=df['id'][x]
    ACCESS_TOKEN = access_token
    PLAYLIST_ENDPOINT = "https://api.spotify.com/v1/playlists/"+id
    headers = {
        "Authorization": "Bearer " + ACCESS_TOKEN,
    }
    response = requests.get(PLAYLIST_ENDPOINT, headers=headers)
    if response.status_code == 200:
        playlist_info = response.json()
        for item in playlist_info['tracks']['items']:
            track = item['track']
            album_id = track['album']['id']
            album_ids.append(album_id)
    else:
        print("Failed to get album:", response.content)

# %%
len(album_ids)
# Out:
# 8803

# %%
album_ids[0]
# Out:
# '6cVfHBcp3AdpYY0bBglkLN'

# %%
ACCESS_TOKEN = access_token
ALBUM_ENDPOINT = "https://api.spotify.com/v1/albums/"+album_ids[0]
headers = {
    "Authorization": "Bearer " + ACCESS_TOKEN,
}
response = requests.get(ALBUM_ENDPOINT, headers=headers)
if response.status_code == 200:
    album_info = response.json()
    print("album name:", album_info["name"])
else:
    print("Failed to get album:", response.content)
# Out:
# album name: Calm Down (with Selena Gomez)

# %%
album={}
album['id']=album_info['id']
album['name']=album_info['name']
album['artists'] = [artist['name'] for artist in album_info['artists']]
album['genre']=album_info['genres']

# %%
df2 = pd.DataFrame([album])
df2
# Out:
#                        id                           name  \
# 0  2b2GHWESCWEuHiCZ2Skedp  Calm Down (with Selena Gomez)
#
#                 artists genre
# 0  [Rema, Selena Gomez]    []

# %%
type(album_info['artists'])
# Out:
# list

# %%
for i in range(len(album_ids)-1):
    ACCESS_TOKEN = access_token
    ALBUM_ENDPOINT = "https://api.spotify.com/v1/albums/"+album_ids[i+1]
    headers = {
        "Authorization": "Bearer " + ACCESS_TOKEN,
    }
    response = requests.get(ALBUM_ENDPOINT, headers=headers)
    if response.status_code == 200:
        album_info = response.json()
    else:
        print("Failed to get album:", response.content)
    album={}
    album['id']=album_info['id']
    album['name']=album_info['name']
    album['artists'] = [artist['name'] for artist in album_info['artists']]
    album['genre']=album_info['genres']
    df2 = df2.append(album, ignore_index=True)
# Out:
# C:\Users\vshar\AppData\Local\Temp\ipykernel_19316\3761333759.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(album, ignore_index=True)
# C:\Users\vshar\AppData\Local\Temp\ipykernel_19316\3761333759.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(album, ignore_index=True)
# C:\Users\vshar\AppData\Local\Temp\ipykernel_19316\3761333759.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(album, ignore_index=True)
# C:\Users\vshar\AppData\Local\Temp\ipykernel_19316\3761333759.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(album, ignore_index=True)
# ...

# %%
df2
# Out:
#                           id                             name  \
# 0     2b2GHWESCWEuHiCZ2Skedp    Calm Down (with Selena Gomez)
# 1     0Ct52rooGyvjv6qXrBPNzm                   Double Fantasy
# 2     1nrVofqDRs7cpWXJ49qTnP                              SOS
# 3     7I0tjwFtxUwBC1vgyeMAax                          Flowers
# 4     7qcSUc5Af63mhfTF60KTEA                         Chemical
# ...                      ...                              ...
# 8798  1zQ6F8gMagKcPL4SoA80cx    One By One (Expanded Edition)
# 8799  49LA20VMk65fQyEaIzYdvf  Yoshimi Battles the Pink Robots
# 8800  0kKfmdca8GY7bDWFWtY801                  Under Rug Swept
# 8801  2kLmv0O8blKeM5HKxLtQrC         Does This Look Infected?
# 8802  0TvOeelcHQXYgPcyQiLhyR         The All-American Rejects
#
#                          artists genre
# 0           [Rema, Selena Gomez]    []
# 1                   [The Weeknd]    []
# 2                          [SZA]    []
# 3                  [Miley Cyrus]    []
# ...

# %%
df2.to_csv("albums.csv", index=False)

# %%
artist_ids=['1Xyo4u8uXC1ZmMpatF05PJ','06HL4z0CvFAxyc27GXpf02','6eUKZXaKkcviH0Ku9w2n3V','5YGY8feqx7naU7z4HrwZM6','5pKCCKE2ajJHZ9KAiaK11H'
           '0EmeFodog0BfCgMzAIvKQp','66CXWjxzNUsdJxJ2JdwvnR','1uNFoZAHBGtllmzznpCI3s','3TVXtAsR1Inumwj472S9r4','1Cs0zKBU1kc0i8ypK3B9ai',
           '7tYKF4w9nC0nq9CsPZTHyP','7dGJo4pcD2V6oG8kP0tJRR','4q3ewBCX7sLwd24euuV69X','6KImCVD70vtIoJWnq6nGn3','7CajNmpbOovFoOoasH2HaY',
headers = {
    "Content-Type": "application/x-www-form-urlencoded",
}
data = {
    "grant_type": "client_credentials",
    "client_id": CLIENT_ID,
    "client_secret": CLIENT_SECRET,
}
response = requests.post(AUTH_URL, headers=headers, data=data)
if response.status_code == 200:
    access_token = response.json()["access_token"]
    print("Access token:", access_token)
else:
    print("Failed to obtain access token:", response.content)
# Out:
# Access token: BQBm8Uk9roKljAYUCtYgVN4Byhn0jNVM86YE3cOYARGPvdadP0BpADqOfF-91E9klxvpBa-jZH4ixMevBVTbXu7d3k4knQr2MPL-XMocMw3_LgQpBEaN

# %%
ACCESS_TOKEN = access_token
ARTIST_ENDPOINT = "https://api.spotify.com/v1/artists/69GGBxA162lTqCwzJG5jLp"
headers = {
    "Authorization": "Bearer " + ACCESS_TOKEN,
}
response = requests.get(ARTIST_ENDPOINT, headers=headers)
if response.status_code == 200:
    artist_info = response.json()
    print("artist name:", artist_info["name"])
else:
    print("Failed to get track:", response.content)
# Out:
# artist name: The Chainsmokers

# %%
artist={}
artist['id']=artist_info['id']
artist['name']=artist_info['name']
artist['genres']=artist_info['genres']
artist
# Out:
# {'id': '69GGBxA162lTqCwzJG5jLp',
#  'name': 'The Chainsmokers',
#  'genres': ['electropop', 'pop', 'tropical house']}

# %%
artist_df=pd.DataFrame([artist])
artist_df
# Out:
#                        id              name                             genres
# 0  69GGBxA162lTqCwzJG5jLp  The Chainsmokers  [electropop, pop, tropical house]

# %%
for x in range(len(artist_ids)-1):
    ACCESS_TOKEN = access_token
    ARTIST_ENDPOINT = "https://api.spotify.com/v1/artists/"+artist_ids[x]
    headers = {
        "Authorization": "Bearer " + ACCESS_TOKEN,
    }
    response = requests.get(ARTIST_ENDPOINT, headers=headers)
    if response.status_code == 200:
        artist_info = response.json()
    else:
        print("Failed to get artist:", response.content)    
    artist['id']=artist_info['id']
    artist['name']=artist_info['name']
    artist['genres']=artist_info['genres']
    artist_df = artist_df.append(artist, ignore_index=True)
# Out:
# C:\Users\vshar\AppData\Local\Temp\ipykernel_19316\4285051697.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   artist_df = artist_df.append(artist, ignore_index=True)
# C:\Users\vshar\AppData\Local\Temp\ipykernel_19316\4285051697.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   artist_df = artist_df.append(artist, ignore_index=True)
# C:\Users\vshar\AppData\Local\Temp\ipykernel_19316\4285051697.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   artist_df = artist_df.append(artist, ignore_index=True)
# C:\Users\vshar\AppData\Local\Temp\ipykernel_19316\4285051697.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
artist_df
# Out:
#                         id              name  \
# 0   69GGBxA162lTqCwzJG5jLp  The Chainsmokers
# 1   1Xyo4u8uXC1ZmMpatF05PJ        The Weeknd
# 2   06HL4z0CvFAxyc27GXpf02      Taylor Swift
# 3   6eUKZXaKkcviH0Ku9w2n3V        Ed Sheeran
# 4   5YGY8feqx7naU7z4HrwZM6       Miley Cyrus
# ..                     ...               ...
# 69  3fMbdgg4jU18AjLCKBhRSm   Michael Jackson
# 70  1KCSPY1glIKqW2TotWuXOR              P!nk
# 71  3nFkdlSjzX9mRTtwJOzDYB             JAY-Z
# 72  1vCWHaC5f2uS3yhpwWbIA6            Avicii
# 73  6l3HvQ5sa6mXTsMTB19rO5           J. Cole
#
#                                                genres
# 0                   [electropop, pop, tropical house]
# 1      [canadian contemporary r&b, canadian pop, pop]
# 2                                               [pop]
# 3                                       [pop, uk pop]
# 4                                               [pop]
# ..                                                ...
# ...

# %%
artist_df.to_csv("artists.csv", index=False)
